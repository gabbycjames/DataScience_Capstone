# %% [markdown]
# # Food Desert Investigation

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Initial Imports

# %% [markdown]
# #### Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# #### Data

# %%
df = pd.read_csv('clean_data.csv')

# %%
df.head()
# Out:
#    FIPS State   County  CHILDPOVRATE15  FARM_TO_SCHOOL15  FDPIR15  \
# 0  1001    AL  autauga            18.8                 0      0.0
# 1  1003    AL  baldwin            19.6                 1      0.0
# 2  1005    AL  barbour            45.2                 0      0.0
# 3  1007    AL     bibb            29.3                 0      0.0
# 4  1009    AL   blount            22.2                 0      0.0
#
#    LACCESS_BLACK15  LACCESS_CHILD10  LACCESS_CHILD15  LACCESS_CHILD_10_15  \
# 0      4216.473194      4822.500269      4616.971480            -4.261872
# 1      3540.965826      7916.131932      7007.972675           -11.472260
# 2      2713.124930       940.419327      1031.927776             9.730601
# 3       419.099942       249.204753       232.642670            -6.645974
# 4        95.842687       384.911607       910.686113           136.596168
#
#    ...  PCT_NHNA10  PCT_NHPI10  PCT_NHWHITE10  PCT_REDUCED_LUNCH10  \
# 0  ...    0.397647    0.040314      77.246156             6.886107
# 1  ...    0.628755    0.043343      83.504787             5.542340
# 2  ...    0.218524    0.087409      46.753105             4.582140
# 3  ...    0.279293    0.030548      75.020729             9.253986
# 4  ...    0.497191    0.031402      88.887338             8.097947
#
#    PCT_REDUCED_LUNCH15  PERCHLDPOV10  PERPOV10  POPLOSS10  POVRATE15  \
# 0             5.492806           0.0       0.0        0.0       12.7
# 1             6.346384           0.0       0.0        0.0       12.9
# 2             2.317528           1.0       1.0        0.0       32.0
# 3             9.060807           1.0       0.0        0.0       22.2
# 4             7.895581           0.0       0.0        0.0       14.7
#
#    Population_Estimate_2015
# 0                     54838
# 1                    202995
# 2                     26294
# 3                     22562
# 4                     57522
#
# [5 rows x 65 columns]

# %%
df.describe()
# Out:
#                FIPS  CHILDPOVRATE15  FARM_TO_SCHOOL15      FDPIR15  \
# count   3140.000000     3140.000000       3140.000000  3140.000000
# mean   30387.632484       23.236306          0.573567     0.157006
# std    15156.372045        9.363672          0.494637     0.970675
# min     1001.000000        3.300000          0.000000     0.000000
# 25%    18178.500000       16.200000          0.000000     0.000000
# 50%    29176.000000       22.300000          1.000000     0.000000
# 75%    45079.500000       29.100000          1.000000     0.000000
# max    56045.000000       61.600000          1.000000    20.000000
#
#        LACCESS_BLACK15  LACCESS_CHILD10  LACCESS_CHILD15  LACCESS_CHILD_10_15  \
# count      3140.000000      3140.000000      3140.000000          3140.000000
# mean       2259.975196      4962.448457      4721.790551           275.148527
# std        8772.373013     13175.136944     12188.860573         11016.241702
# min           0.000000         0.000000         0.000000          -100.000000
# 25%           7.000000       365.182063       357.517444           -10.797016
# 50%          88.031385       937.561324       951.889339            -0.038024
# 75%        1003.774030      3009.332967      2982.926315             7.006581
# max      167913.190400    260308.794100    219002.492900        592130.563800
#
#        LACCESS_HHNV10  LACCESS_HHNV15  ...   PCT_NHNA10   PCT_NHPI10  \
# count     3140.000000     3140.000000  ...  3140.000000  3140.000000
# mean       660.900434      673.485260  ...     1.812958     0.080520
# std       1121.570831     1100.582981  ...     7.241848     0.946025
# min          0.000000        0.000000  ...     0.000000     0.000000
# 25%        118.110707      126.004765  ...     0.194960     0.010005
# 50%        320.013520      340.348323  ...     0.304993     0.022943
# 75%        706.477808      754.501764  ...     0.625350     0.046501
# max      16334.423180    13845.220200  ...    86.319184    48.888889
#
#        PCT_NHWHITE10  PCT_REDUCED_LUNCH10  PCT_REDUCED_LUNCH15  PERCHLDPOV10  \
# count    3140.000000          3140.000000          3140.000000   3140.000000
# mean       78.343850             8.501296             7.011192      0.224841
# std        19.805889             3.277897             3.800416      0.417544
# min         2.860408             0.000000             0.000000      0.000000
# 25%        66.994751             6.573317             4.912017      0.000000
# 50%        85.772028             8.119723             7.075466      0.000000
# 75%        94.175301            10.033524             9.187047      0.000000
# max        99.163180            57.417468            35.714286      1.000000
#
#           PERPOV10    POPLOSS10    POVRATE15  Population_Estimate_2015
# count  3140.000000  3140.000000  3140.000000              3.140000e+03
# mean      0.111783     0.168471    16.259283              1.021402e+05
# std       0.315150     0.374344     6.441990              3.282909e+05
# min       0.000000     0.000000     3.400000              8.800000e+01
# 25%       0.000000     0.000000    11.500000              1.095400e+04
# 50%       0.000000     0.000000    15.200000              2.564850e+04
# 75%       0.000000     0.000000    19.700000              6.749650e+04
# max       1.000000     1.000000    47.400000              1.009704e+07
#
# [8 rows x 63 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FIPS                       3140 non-null   int64
#  1   State                      3140 non-null   object
#  2   County                     3140 non-null   object
#  3   CHILDPOVRATE15             3140 non-null   float64
#  4   FARM_TO_SCHOOL15           3140 non-null   int64
#  5   FDPIR15                    3140 non-null   float64
#  6   LACCESS_BLACK15            3140 non-null   float64
#  7   LACCESS_CHILD10            3140 non-null   float64
#  8   LACCESS_CHILD15            3140 non-null   float64
#  9   LACCESS_CHILD_10_15        3140 non-null   float64
#  10  LACCESS_HHNV10             3140 non-null   float64
#  11  LACCESS_HHNV15             3140 non-null   float64
#  12  LACCESS_HISP15             3140 non-null   float64
#  13  LACCESS_LOWI10             3140 non-null   float64
#  14  LACCESS_LOWI15             3140 non-null   float64
#  15  LACCESS_MULTIR15           3140 non-null   float64
#  16  LACCESS_NHASIAN15          3140 non-null   float64
#  17  LACCESS_NHNA15             3140 non-null   float64
#  18  LACCESS_NHPI15             3140 non-null   float64
#  19  LACCESS_POP10              3140 non-null   float64
#  20  LACCESS_POP15              3140 non-null   float64
#  21  LACCESS_SENIORS10          3140 non-null   float64
#  22  LACCESS_SENIORS15          3140 non-null   float64
#  23  LACCESS_SNAP15             3140 non-null   float64
#  24  LACCESS_WHITE15            3140 non-null   float64
#  25  MEDHHINC15                 3140 non-null   float64
#  26  PCH_LACCESS_HHNV_10_15     3140 non-null   float64
#  27  PCH_LACCESS_LOWI_10_15     3140 non-null   float64
#  28  PCH_LACCESS_POP_10_15      3140 non-null   float64
#  29  PCH_LACCESS_SENIORS_10_15  3140 non-null   float64
#  30  PCT_18YOUNGER10            3140 non-null   float64
#  31  PCT_65OLDER10              3140 non-null   float64
#  32  PCT_FREE_LUNCH10           3140 non-null   float64
#  33  PCT_FREE_LUNCH15           3140 non-null   float64
#  34  PCT_HISP10                 3140 non-null   float64
#  35  PCT_LACCESS_BLACK15        3140 non-null   float64
#  36  PCT_LACCESS_CHILD10        3140 non-null   float64
#  37  PCT_LACCESS_CHILD15        3140 non-null   float64
#  38  PCT_LACCESS_HHNV10         3140 non-null   float64
#  39  PCT_LACCESS_HHNV15         3140 non-null   float64
#  40  PCT_LACCESS_HISP15         3140 non-null   float64
#  41  PCT_LACCESS_LOWI10         3140 non-null   float64
#  42  PCT_LACCESS_LOWI15         3140 non-null   float64
#  43  PCT_LACCESS_MULTIR15       3140 non-null   float64
#  44  PCT_LACCESS_NHASIAN15      3140 non-null   float64
#  45  PCT_LACCESS_NHNA15         3140 non-null   float64
#  46  PCT_LACCESS_NHPI15         3140 non-null   float64
#  47  PCT_LACCESS_POP10          3140 non-null   float64
#  48  PCT_LACCESS_POP15          3140 non-null   float64
#  49  PCT_LACCESS_SENIORS10      3140 non-null   float64
#  50  PCT_LACCESS_SENIORS15      3140 non-null   float64
#  51  PCT_LACCESS_SNAP15         3140 non-null   float64
#  52  PCT_LACCESS_WHITE15        3140 non-null   float64
#  53  PCT_NHASIAN10              3140 non-null   float64
#  54  PCT_NHBLACK10              3140 non-null   float64
#  55  PCT_NHNA10                 3140 non-null   float64
#  56  PCT_NHPI10                 3140 non-null   float64
#  57  PCT_NHWHITE10              3140 non-null   float64
#  58  PCT_REDUCED_LUNCH10        3140 non-null   float64
#  59  PCT_REDUCED_LUNCH15        3140 non-null   float64
#  60  PERCHLDPOV10               3140 non-null   float64
#  61  PERPOV10                   3140 non-null   float64
#  62  POPLOSS10                  3140 non-null   float64
#  63  POVRATE15                  3140 non-null   float64
#  64  Population_Estimate_2015   3140 non-null   int64
# dtypes: float64(60), int64(3), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Dependent Variable

# %% [markdown]
# #### Initial Exploration

# %%
plt.figure(figsize=(8,8))
pov_by_state = df.groupby("State")["POVRATE15"].mean().sort_values(ascending=True)
pov_by_state.plot(kind="bar", title="Poverty Rate by State")
plt.show()

# %%
plt.figure(figsize=(8,8))
median_income = df.groupby("State")["MEDHHINC15"].mean().sort_values(ascending=True)
median_income.plot(kind="bar", title="Median Household Income by State")
plt.show()

# %% [markdown]
# #### Correlation

# %%
#df.iloc[:,3:64].corr()

# %%
corr = df.corr(numeric_only=True)

# %%
abs_corr = corr.abs()

# %%
s = abs_corr.unstack()
so = s.sort_values(kind='quicksort', ascending=False)
so = so[so > 0.6]
so = so[so < 1.0]

# %% [markdown]
# Visualizing the correlation of numerical columns

# %%
#_ = sns.pairplot(df.iloc[:,3:64])
#plt.show()

# %%
plt.figure(figsize=(20,20))
_ = sns.heatmap(df.corr(numeric_only=True), annot=False)
plt.show()

# %%
sorted_correlation = pd.DataFrame(so)
sorted_correlation.head()
# Out:
#                                                             0
# PCH_LACCESS_POP_10_15     PCH_LACCESS_LOWI_10_15     0.999987
# PCH_LACCESS_LOWI_10_15    PCH_LACCESS_POP_10_15      0.999987
# PCH_LACCESS_SENIORS_10_15 PCH_LACCESS_LOWI_10_15     0.999808
# PCH_LACCESS_LOWI_10_15    PCH_LACCESS_SENIORS_10_15  0.999808
# PCH_LACCESS_SENIORS_10_15 PCH_LACCESS_POP_10_15      0.999695

# %%
plt.figure(figsize=(20,20))
_ = sns.heatmap(sorted_correlation, annot=False)
plt.ylabel('Correlation of Column Variables')
plt.show()

# %%
# Plot POVRATE15 against Median Household Income 2015
_ = sns.scatterplot(data=df, x='MEDHHINC15', y='POVRATE15', alpha=0.5)
plt.show()

# %%
# Plot POVRATE15 against Percent Free Lunch 2015
_ = sns.scatterplot(data=df, x='POVRATE15', y='PCT_FREE_LUNCH15')
plt.show()

# %%
# Plot POVRATE15 against Number of People with Low Access 2015
_ = sns.scatterplot(data=df, x='POVRATE15', y='LACCESS_POP15')
plt.show()

# %%
df['LACCESS_POP15'].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df['LACCESS_POP15'].corr()
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'

# %% [markdown]
# #### Poverty Rate

# %%
_ = plt.hist(df['POVRATE15'], bins=20, color='g', alpha=0.5)
_ = plt.hist(df['CHILDPOVRATE15'], bins=20, color='b', alpha=0.5)
plt.xlabel('Percent in Poverty')
plt.ylabel('Frequency')
plt.title('Distribution of Poverty Rates')
plt.show()

# %%
df['POVRATE15'].describe()
# Out:
# count    3140.000000
# mean       16.259283
# std         6.441990
# min         3.400000
# 25%        11.500000
# 50%        15.200000
# 75%        19.700000
# max        47.400000
# Name: POVRATE15, dtype: float64
